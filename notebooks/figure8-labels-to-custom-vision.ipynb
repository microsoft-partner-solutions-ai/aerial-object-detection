# %% [markdown]
# # Import Figure8 labels to Custom Vision Service

# %%
# install packages if needed
import sys
# !{sys.executable} -m pip install azure-cognitiveservices-vision-customvision
# !{sys.executable} -m pip install azureml-sdk
# !{sys.executable} -m pip install azureml-contrib-dataset
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install Pillow

# %%
import json, os, shutil, requests, math
import pandas as pd

from PIL import Image
from io import BytesIO

from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateEntry, Region
from msrest.authentication import ApiKeyCredentials

# azureml-core of version 1.0.72 or higher is required
# azureml-dataprep[pandas] of version 1.1.34 or higher is required
# azureml-contrib-dataset of version 1.0.72 or higher is required

# %% [markdown]
# ## 1. Set up Custom Vision project

# %% [markdown]
# Enter the details for your Custom Vision endpoint and training key below:

# %%
# ENDPOINT = 'https://YOUR_REGION.api.cognitive.microsoft.com'
# training_key = "<CUSTOM VISION TRAINING KEY>"

ENDPOINT = 'https://westus2.api.cognitive.microsoft.com'
training_key = "bc43db20938e453b89b5fffc9ccbc8f9"

credentials = ApiKeyCredentials(in_headers={"Training-key": training_key})
trainer = CustomVisionTrainingClient(endpoint=ENDPOINT, credentials=credentials)

# %% [markdown]
# ### Option 1: Create new project

# %% [markdown]
# The below cell will create a new Custom Vision project.  Enter a name for your project below:
#
# Note: If you have an existing project, skip to the next cell.

# %%
# project_name = "<PROJECT NAME>"
project_name = "test2"

# Find the object detection domain
obj_detection_domain = next(domain for domain in trainer.get_domains() if domain.type == "ObjectDetection" and domain.name == "General")

# Create a new project
print("Creating new project...")
project = trainer.create_project(project_name, domain_id=obj_detection_domain.id)
print(project.name, "project created")
# Out:
# Creating new project...
# test2 project created

# %% [markdown]
# ### Option 2: Update existing Custom Vision project

# %% [markdown]
# The below cell will get an existing project by ID.  Enter your project ID below (you can retrieve this ID from your project in the [Custom Vision portal](http://customvision.ai)):

# %%
project_id = "<PROJECT ID>"

# Get existing project
project = trainer.get_project(project_id = project_id) 
print(project.name, "project retrieved")

# %% [markdown]
# ## 2. Read labeled dataset from csv

# %%
# filename = "<PATH TO CSV FILE WITH LABELS>" 
filename = "../data/mantech_final_subset.csv" 

df = pd.read_csv(filename)
df = df[['annotation','image_url','image_name']]
df.head()
# Out:
#                                           annotation  \
# 0  [{"id": "1322953c-2209-4113-8b51-b2a2d2311e69"...
# 1  [{"id": "1e8fa8b9-e530-4b45-bd56-eb30f5dfc9ef"...
# 2  [{"id": "bf99ed99-f008-46a0-b0ef-3588e329dd91"...
# 3  [{"id": "34b9ff40-bfd7-47a0-9fd3-e6f9c72928f6"...
# 4  [{"id": "521e21d4-99a2-44ad-abb1-3c4aa4d31bfb"...
#
#                                            image_url        image_name
# 0  https://cf-315f62h.s3.us-east-1.amazonaws.com/...  SatImg  (13).jpg
# 1  https://cf-315f62h.s3.us-east-1.amazonaws.com/...  SatImg  (13).jpg
# 2  https://cf-315f62h.s3.us-east-1.amazonaws.com/...  SatImg  (13).jpg
# 3  https://cf-315f62h.s3.us-east-1.amazonaws.com/...  SatImg  (13).jpg
# 4  https://cf-315f62h.s3.us-east-1.amazonaws.com/...  SatImg  (13).jpg

# %% [markdown]
# ### Prep images and format tags for Custom Vision

# %%
def get_image_from_url(url):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    width = img.size[0]
    height = img.size[1]
    img_bytes = image_to_bytes(img)
    return img_bytes, width, height

def get_bbox(label, width, height):
    l = label['x']/width
    t = label['y']/height
    w = label['w']/width
    h = label['h']/height  
    return l,t,w,h

def image_to_bytes(image):
    # Convert image to byte stream
    img_byte_arr = BytesIO()
    image.save(img_byte_arr, format='PNG')
    img_byte_arr = img_byte_arr.getvalue()
    return img_byte_arr

# %%
tagged_ims = []
tags = trainer.get_tags(project.id)

num_labels = df.shape[0]

previous_url = ''
regions = []
for i, row in df.iterrows():
    
    # handle first as edge case to get pointer to previous image url
    if i == 0:
        previous_url = row['image_url']
        img_bytes, width, height = get_image_from_url(previous_url)
        filename = row['image_name']
        print(f"Processing image: {filename}, label {i}/{num_labels}")
        
    # get image url and label
    img_url = row['image_url']
    label = json.loads(row['annotation'])
    
    # retrieve tag object by label name
    label_name = 'vehicle'
    try:
        index = [x.name for x in tags].index(label_name)
        tag = tags[index]
    # create tag if it does not exist yet
    except:
        print("Creating new tag for:", label_name)
        tag = trainer.create_tag(project.id, label_name)
        tags = trainer.get_tags(project.id)
      
    # create bounding box regions
    coords = label[0]['coordinates']   
    l,t,w,h = get_bbox(coords, width, height)
    regions.append(Region(tag_id=tag.id,left=l,top=t,width=w,height=h))
    
    # when we get to a new image
    if img_url != previous_url:
        
        # create image file entry for all data from previous image and append to image set
        tagged_ims.append(ImageFileCreateEntry(name=filename, contents=img_bytes, regions=regions))
    
        regions = []
        
        # get info from new image
        img_bytes, width, height = get_image_from_url(img_url)
        filename = row['image_name']

        print(f"Processing image: {filename}")
        
    # update previous url to current
    previous_url = img_url
# Out:
# Processing image: SatImg  (13).jpg
# Creating new tag for: vehicle
# Processing image: SatImg  (19).jpg
# Processing image: SatImg  (24).jpg
# Processing image: SatImg  (26).jpg
# Processing image: SatImg  (27).jpg
# Processing image: SatImg  (28).jpg
# Processing image: SatImg  (29).jpg
# Processing image: SatImg  (30).jpg
# Processing image: SatImg  (50).jpg
# Processing image: SatImg  (56).jpg
# Processing image: SatImg  (57).jpg
# Processing image: SatImg  (58).jpg
# Processing image: SatImg  (59).jpg
# Processing image: SatImg  (80).jpg
# Processing image: SatImg  (86).jpg
# Processing image: SatImg  (87).jpg
# Processing image: SatImg  (88).jpg
# Processing image: SatImg  (89).jpg
# Processing image: SatImg  (117).jpg
# Processing image: SatImg  (181).jpg
# Processing image: SatImg  (251).jpg
# Processing image: SatImg  (252).jpg
# Processing image: SatImg  (273).jpg
# Processing image: SatImg  (274).jpg
# Processing image: SatImg  (292).jpg
# Processing image: SatImg  (293).jpg
# Processing image: SatImg  (294).jpg
# Processing image: SatImg  (295).jpg
# Processing image: SatImg  (296).jpg
# Processing image: SatImg  (311).jpg
# Processing image: SatImg  (312).jpg
# Processing image: SatImg  (313).jpg
# Processing image: SatImg  (314).jpg
# Processing image: SatImg  (315).jpg
# Processing image: SatImg  (332).jpg
# Processing image: SatImg  (348).jpg
# Processing image: SatImg  (349).jpg
# Processing image: SatImg  (350).jpg
# Processing image: SatImg  (351).jpg
# Processing image: SatImg  (352).jpg
# Processing image: SatImg  (362).jpg
# Processing image: SatImg  (366).jpg
# Processing image: SatImg  (368).jpg
# Processing image: SatImg  (382).jpg
# Processing image: SatImg  (383).jpg
# Processing image: SatImg  (384).jpg
# Processing image: SatImg  (397).jpg
# Processing image: SatImg  (451).jpg
# Processing image: SatImg  (452).jpg
# Processing image: SatImg  (504).jpg
# Processing image: SatImg  (819).jpg
# Processing image: SatImg  (858).jpg
# Processing image: SatImg  (859).jpg
# Processing image: SatImg  (895).jpg
# Processing image: SatImg  (996).jpg
# Processing image: SatImg  (998).jpg
# Processing image: SatImg  (1025).jpg
# Processing image: SatImg  (1032).jpg
# Processing image: SatImg  (1051).jpg
# Processing image: SatImg  (1052).jpg
# Processing image: SatImg  (1053).jpg
# Processing image: SatImg  (1055).jpg
# Processing image: SatImg  (1056).jpg
# Processing image: SatImg  (1058).jpg
# Processing image: SatImg  (1059).jpg
# Processing image: SatImg  (1066).jpg
# Processing image: SatImg  (1067).jpg
# Processing image: SatImg  (1084).jpg
# Processing image: SatImg  (1098).jpg
# Processing image: SatImg  (1099).jpg
# Processing image: SatImg  (1100).jpg
# Processing image: SatImg  (1101).jpg
# Processing image: SatImg  (1102).jpg
# Processing image: SatImg  (1121).jpg
# Processing image: SatImg  (1128).jpg
# Processing image: SatImg  (1129).jpg
# Processing image: SatImg  (1130).jpg
# Processing image: SatImg  (1131).jpg
# Processing image: SatImg  (1132).jpg
# Processing image: Titan  (12).jpg
# Processing image: Titan  (23).jpg
# Processing image: Titan  (24).jpg
# Processing image: Titan  (25).jpg
# Processing image: Titan  (33).jpg
# Processing image: Titan  (46).jpg
# Processing image: Titan  (48).jpg
# Processing image: Titan  (57).jpg
# Processing image: Titan  (134).jpg
# Processing image: Titan  (135).jpg
# Processing image: Titan  (136).jpg
# Processing image: Titan  (137).jpg
# Processing image: Titan  (145).jpg
# Processing image: Titan  (146).jpg
# Processing image: Titan  (148).jpg
# Processing image: Titan  (149).jpg
# Processing image: Titan  (158).jpg
# Processing image: Titan  (160).jpg
# Processing image: Titan  (161).jpg
# Processing image: Titan  (172).jpg
# Processing image: Titan  (173).jpg
# Processing image: Titan  (181).jpg
# Processing image: Titan  (183).jpg
# Processing image: Titan  (184).jpg
# Processing image: Titan  (194).jpg
# Processing image: Titan  (219).jpg
# Processing image: Titan  (220).jpg
# Processing image: Titan  (221).jpg
# Processing image: Titan  (231).jpg
# Processing image: Titan  (232).jpg
# Processing image: Titan  (233).jpg
# Processing image: Titan  (242).jpg
# Processing image: Titan  (244).jpg
# Processing image: Titan  (245).jpg
# Processing image: Titan  (255).jpg
# Processing image: Titan  (257).jpg
# Processing image: Titan  (268).jpg
# Processing image: Titan  (279).jpg
# Processing image: Titan  (280).jpg
# Processing image: Titan  (291).jpg
# Processing image: Titan  (339).jpg
# Processing image: Titan  (349).jpg
# Processing image: Titan  (352).jpg
# Processing image: Titan  (353).jpg
# Processing image: Titan  (358).jpg
# Processing image: Titan  (360).jpg
# Processing image: Titan  (376).jpg
# Processing image: Titan  (377).jpg
# Processing image: uav  (341).jpg
# Processing image: uav  (342).jpg
# Processing image: uav  (345).jpg
# Processing image: uav  (346).jpg
# Processing image: uav  (348).jpg
# Processing image: uav  (349).jpg
# Processing image: uav  (350).jpg
# Processing image: uav  (352).jpg
# Processing image: uav  (353).jpg
# Processing image: uav  (367).jpg
# Processing image: uav  (368).jpg
# Processing image: uav  (371).jpg
# Processing image: uav  (373).jpg
# Processing image: uav  (376).jpg
# Processing image: uav  (377).jpg
# Processing image: SatImg  (1).jpg
# Processing image: SatImg  (2).jpg
# Processing image: SatImg  (6).jpg
# Processing image: SatImg  (7).jpg
# Processing image: SatImg  (8).jpg
# Processing image: SatImg  (9).jpg
# Processing image: SatImg  (10).jpg
# Processing image: SatImg  (12).jpg
# Processing image: SatImg  (14).jpg
# Processing image: SatImg  (15).jpg
# Processing image: SatImg  (16).jpg
# Processing image: SatImg  (17).jpg
# Processing image: SatImg  (20).jpg
# Processing image: SatImg  (21).jpg
# Processing image: SatImg  (22).jpg
# Processing image: SatImg  (23).jpg
# Processing image: SatImg  (25).jpg
# Processing image: SatImg  (31).jpg
# Processing image: SatImg  (33).jpg
# Processing image: SatImg  (34).jpg
# Processing image: SatImg  (35).jpg
# Processing image: SatImg  (36).jpg
# Processing image: SatImg  (37).jpg
# Processing image: SatImg  (39).jpg
# Processing image: SatImg  (40).jpg
# Processing image: SatImg  (41).jpg
# Processing image: SatImg  (42).jpg
# Processing image: SatImg  (43).jpg
# Processing image: SatImg  (44).jpg
# Processing image: SatImg  (45).jpg
# Processing image: SatImg  (46).jpg
# Processing image: SatImg  (47).jpg
# Processing image: SatImg  (48).jpg
# Processing image: SatImg  (49).jpg
# Processing image: SatImg  (52).jpg
# Processing image: SatImg  (53).jpg
# Processing image: SatImg  (54).jpg
# Processing image: SatImg  (55).jpg
# Processing image: SatImg  (60).jpg
# Processing image: SatImg  (61).jpg
# Processing image: SatImg  (62).jpg
# Processing image: SatImg  (63).jpg
# Processing image: SatImg  (66).jpg
# Processing image: SatImg  (67).jpg
# Processing image: SatImg  (70).jpg
# Processing image: SatImg  (72).jpg
# Processing image: SatImg  (73).jpg
# Processing image: SatImg  (74).jpg
# Processing image: SatImg  (75).jpg
# Processing image: SatImg  (76).jpg
# Processing image: SatImg  (77).jpg
# Processing image: SatImg  (78).jpg
# Processing image: SatImg  (79).jpg
# Processing image: SatImg  (81).jpg
# Processing image: SatImg  (82).jpg
# Processing image: SatImg  (83).jpg
# Processing image: SatImg  (84).jpg
# Processing image: SatImg  (85).jpg
# Processing image: SatImg  (95).jpg
# Processing image: SatImg  (97).jpg
# Processing image: SatImg  (98).jpg
# Processing image: SatImg  (101).jpg
# Processing image: SatImg  (102).jpg
# Processing image: SatImg  (103).jpg
# Processing image: SatImg  (104).jpg
# Processing image: SatImg  (105).jpg
# Processing image: SatImg  (106).jpg
# Processing image: SatImg  (111).jpg
# Processing image: SatImg  (112).jpg
# Processing image: SatImg  (113).jpg
# Processing image: SatImg  (114).jpg
# Processing image: SatImg  (115).jpg
# Processing image: SatImg  (116).jpg
# Processing image: SatImg  (118).jpg
# Processing image: SatImg  (123).jpg
# Processing image: SatImg  (124).jpg
# Processing image: SatImg  (125).jpg
# Processing image: SatImg  (126).jpg
# Processing image: SatImg  (127).jpg
# Processing image: SatImg  (128).jpg
# Processing image: SatImg  (129).jpg
# Processing image: SatImg  (134).jpg
# Processing image: SatImg  (137).jpg
# Processing image: SatImg  (139).jpg
# Processing image: SatImg  (142).jpg
# Processing image: SatImg  (143).jpg
# Processing image: SatImg  (144).jpg
# Processing image: SatImg  (145).jpg
# Processing image: SatImg  (151).jpg
# Processing image: SatImg  (153).jpg
# Processing image: SatImg  (154).jpg
# Processing image: SatImg  (155).jpg
# Processing image: SatImg  (156).jpg
# Processing image: SatImg  (166).jpg
# Processing image: SatImg  (168).jpg
# Processing image: SatImg  (169).jpg
# Processing image: SatImg  (170).jpg
# Processing image: SatImg  (171).jpg
# Processing image: SatImg  (177).jpg
# Processing image: SatImg  (178).jpg
# Processing image: SatImg  (179).jpg
# Processing image: SatImg  (180).jpg
# Processing image: SatImg  (190).jpg
# Processing image: SatImg  (191).jpg
# Processing image: SatImg  (192).jpg
# Processing image: SatImg  (193).jpg
# Processing image: SatImg  (201).jpg
# Processing image: SatImg  (202).jpg
# Processing image: SatImg  (203).jpg
# Processing image: SatImg  (204).jpg
# Processing image: SatImg  (205).jpg
# Processing image: SatImg  (206).jpg
# Processing image: SatImg  (212).jpg
# Processing image: SatImg  (216).jpg
# Processing image: SatImg  (217).jpg
# Processing image: SatImg  (218).jpg
# Processing image: SatImg  (220).jpg
# Processing image: SatImg  (226).jpg
# Processing image: SatImg  (227).jpg
# Processing image: SatImg  (228).jpg
# Processing image: SatImg  (229).jpg
# Processing image: SatImg  (230).jpg
# Processing image: SatImg  (231).jpg
# Processing image: SatImg  (232).jpg
# Processing image: SatImg  (234).jpg
# Processing image: SatImg  (235).jpg
# Processing image: SatImg  (242).jpg
# Processing image: SatImg  (245).jpg
# Processing image: SatImg  (249).jpg
# Processing image: SatImg  (250).jpg
# Processing image: SatImg  (254).jpg
# Processing image: SatImg  (261).jpg
# Processing image: SatImg  (267).jpg
# Processing image: SatImg  (268).jpg
# Processing image: SatImg  (269).jpg
# Processing image: SatImg  (270).jpg
# Processing image: SatImg  (271).jpg
# Processing image: SatImg  (272).jpg
# Processing image: SatImg  (275).jpg
# Processing image: SatImg  (276).jpg
# Processing image: SatImg  (277).jpg
# Processing image: SatImg  (278).jpg
# Processing image: SatImg  (279).jpg
# Processing image: SatImg  (282).jpg
# Processing image: SatImg  (285).jpg
# Processing image: SatImg  (288).jpg
# Processing image: SatImg  (289).jpg
# Processing image: SatImg  (290).jpg
# Processing image: SatImg  (291).jpg
# Processing image: SatImg  (297).jpg
# Processing image: SatImg  (298).jpg
# Processing image: SatImg  (299).jpg
# Processing image: SatImg  (302).jpg
# Processing image: SatImg  (303).jpg
# Processing image: SatImg  (304).jpg
# Processing image: SatImg  (306).jpg
# Processing image: SatImg  (307).jpg
# Processing image: SatImg  (308).jpg
# Processing image: SatImg  (309).jpg
# Processing image: SatImg  (310).jpg
# Processing image: SatImg  (316).jpg
# Processing image: SatImg  (317).jpg
# Processing image: SatImg  (319).jpg
# Processing image: SatImg  (320).jpg
# Processing image: SatImg  (321).jpg
# Processing image: SatImg  (325).jpg
# Processing image: SatImg  (327).jpg
# Processing image: SatImg  (328).jpg
# Processing image: SatImg  (329).jpg
# Processing image: SatImg  (330).jpg
# Processing image: SatImg  (331).jpg
# Processing image: SatImg  (333).jpg
# Processing image: SatImg  (334).jpg
# Processing image: SatImg  (338).jpg
# Processing image: SatImg  (339).jpg
# Processing image: SatImg  (342).jpg
# Processing image: SatImg  (344).jpg
# Processing image: SatImg  (346).jpg
# Processing image: SatImg  (347).jpg
# Processing image: SatImg  (353).jpg
# Processing image: SatImg  (359).jpg
# Processing image: SatImg  (365).jpg
# Processing image: SatImg  (367).jpg
# Processing image: SatImg  (369).jpg
# Processing image: SatImg  (370).jpg
# Processing image: SatImg  (373).jpg
# Processing image: SatImg  (378).jpg
# Processing image: SatImg  (379).jpg
# Processing image: SatImg  (380).jpg
# Processing image: SatImg  (381).jpg
# Processing image: SatImg  (385).jpg
# Processing image: SatImg  (386).jpg
# Processing image: SatImg  (387).jpg
# Processing image: SatImg  (395).jpg
# Processing image: SatImg  (396).jpg
# Processing image: SatImg  (398).jpg
# Processing image: SatImg  (399).jpg
# Processing image: SatImg  (400).jpg
# Processing image: SatImg  (401).jpg
# Processing image: SatImg  (402).jpg
# Processing image: SatImg  (403).jpg
# Processing image: SatImg  (411).jpg
# Processing image: SatImg  (412).jpg
# Processing image: SatImg  (413).jpg
# Processing image: SatImg  (414).jpg
# Processing image: SatImg  (415).jpg
# Processing image: SatImg  (416).jpg
# Processing image: SatImg  (417).jpg
# Processing image: SatImg  (420).jpg
# Processing image: SatImg  (421).jpg
# Processing image: SatImg  (422).jpg
# Processing image: SatImg  (423).jpg
# Processing image: SatImg  (424).jpg
# Processing image: SatImg  (425).jpg
# Processing image: SatImg  (426).jpg
# Processing image: SatImg  (427).jpg
# Processing image: SatImg  (428).jpg
# Processing image: SatImg  (429).jpg
# Processing image: SatImg  (430).jpg
# Processing image: SatImg  (431).jpg
# Processing image: SatImg  (432).jpg
# Processing image: SatImg  (433).jpg
# Processing image: SatImg  (434).jpg
# Processing image: SatImg  (436).jpg
# Processing image: SatImg  (437).jpg
# Processing image: SatImg  (438).jpg
# Processing image: SatImg  (439).jpg
# Processing image: SatImg  (440).jpg
# Processing image: SatImg  (441).jpg
# Processing image: SatImg  (442).jpg
# Processing image: SatImg  (448).jpg
# Processing image: SatImg  (449).jpg
# Processing image: SatImg  (450).jpg
# Processing image: SatImg  (453).jpg
# Processing image: SatImg  (454).jpg
# Processing image: SatImg  (458).jpg
# Processing image: SatImg  (459).jpg
# Processing image: SatImg  (460).jpg
# Processing image: SatImg  (461).jpg
# Processing image: SatImg  (462).jpg
# Processing image: SatImg  (463).jpg
# Processing image: SatImg  (464).jpg
# Processing image: SatImg  (466).jpg
# Processing image: SatImg  (467).jpg
# Processing image: SatImg  (469).jpg
# Processing image: SatImg  (470).jpg
# Processing image: SatImg  (471).jpg
# Processing image: SatImg  (472).jpg
# Processing image: SatImg  (473).jpg
# Processing image: SatImg  (474).jpg
# Processing image: SatImg  (475).jpg
# Processing image: SatImg  (476).jpg
# Processing image: SatImg  (477).jpg
# Processing image: SatImg  (478).jpg
# Processing image: SatImg  (479).jpg
# Processing image: SatImg  (480).jpg
# Processing image: SatImg  (481).jpg
# Processing image: SatImg  (482).jpg
# Processing image: SatImg  (483).jpg
# Processing image: SatImg  (484).jpg
# Processing image: SatImg  (485).jpg
# Processing image: SatImg  (486).jpg
# Processing image: SatImg  (487).jpg
# Processing image: SatImg  (488).jpg
# Processing image: SatImg  (489).jpg
# Processing image: SatImg  (494).jpg
# Processing image: SatImg  (495).jpg
# Processing image: SatImg  (496).jpg
# Processing image: SatImg  (497).jpg
# Processing image: SatImg  (498).jpg
# Processing image: SatImg  (499).jpg
# Processing image: SatImg  (500).jpg
# Processing image: SatImg  (501).jpg
# Processing image: SatImg  (502).jpg
# Processing image: SatImg  (503).jpg
# Processing image: SatImg  (506).jpg
# Processing image: SatImg  (507).jpg
# Processing image: SatImg  (508).jpg
# Processing image: SatImg  (509).jpg
# Processing image: SatImg  (510).jpg
# Processing image: SatImg  (511).jpg
# Processing image: SatImg  (520).jpg
# Processing image: SatImg  (521).jpg
# Processing image: SatImg  (522).jpg
# Processing image: SatImg  (523).jpg
# Processing image: SatImg  (524).jpg
# Processing image: SatImg  (532).jpg
# Processing image: SatImg  (533).jpg
# Processing image: SatImg  (534).jpg
# Processing image: SatImg  (545).jpg
# Processing image: SatImg  (549).jpg
# Processing image: SatImg  (551).jpg
# Processing image: SatImg  (569).jpg
# Processing image: SatImg  (570).jpg
# Processing image: SatImg  (571).jpg
# Processing image: SatImg  (572).jpg
# Processing image: SatImg  (573).jpg
# Processing image: SatImg  (574).jpg
# Processing image: SatImg  (597).jpg
# Processing image: SatImg  (598).jpg
# Processing image: SatImg  (599).jpg
# Processing image: SatImg  (622).jpg
# Processing image: SatImg  (623).jpg
# Processing image: SatImg  (625).jpg
# Processing image: SatImg  (627).jpg
# Processing image: SatImg  (628).jpg
# Processing image: SatImg  (634).jpg
# Processing image: SatImg  (635).jpg
# Processing image: SatImg  (652).jpg
# Processing image: SatImg  (653).jpg
# Processing image: SatImg  (654).jpg
# Processing image: SatImg  (655).jpg
# Processing image: SatImg  (656).jpg
# Processing image: SatImg  (657).jpg
# Processing image: SatImg  (658).jpg
# Processing image: SatImg  (659).jpg
# Processing image: SatImg  (660).jpg
# Processing image: SatImg  (661).jpg
# Processing image: SatImg  (693).jpg
# Processing image: SatImg  (694).jpg
# Processing image: SatImg  (695).jpg
# Processing image: SatImg  (696).jpg
# Processing image: SatImg  (697).jpg
# Processing image: SatImg  (699).jpg
# Processing image: SatImg  (700).jpg
# Processing image: SatImg  (701).jpg
# Processing image: SatImg  (705).jpg
# Processing image: SatImg  (706).jpg
# Processing image: SatImg  (732).jpg
# Processing image: SatImg  (733).jpg
# Processing image: SatImg  (734).jpg
# Processing image: SatImg  (735).jpg
# Processing image: SatImg  (736).jpg
# Processing image: SatImg  (737).jpg
# Processing image: SatImg  (738).jpg
# Processing image: SatImg  (739).jpg
# Processing image: SatImg  (740).jpg
# Processing image: SatImg  (741).jpg
# Processing image: SatImg  (742).jpg
# Processing image: SatImg  (743).jpg
# Processing image: SatImg  (747).jpg
# Processing image: SatImg  (759).jpg
# Processing image: SatImg  (772).jpg
# Processing image: SatImg  (773).jpg
# Processing image: SatImg  (774).jpg
# Processing image: SatImg  (775).jpg
# Processing image: SatImg  (776).jpg
# Processing image: SatImg  (777).jpg
# Processing image: SatImg  (778).jpg
# Processing image: SatImg  (779).jpg
# Processing image: SatImg  (780).jpg
# Processing image: SatImg  (781).jpg
# Processing image: SatImg  (782).jpg
# Processing image: SatImg  (783).jpg
# Processing image: SatImg  (784).jpg
# Processing image: SatImg  (785).jpg
# Processing image: SatImg  (786).jpg
# Processing image: SatImg  (795).jpg
# Processing image: SatImg  (796).jpg
# Processing image: SatImg  (797).jpg
# Processing image: SatImg  (798).jpg
# Processing image: SatImg  (799).jpg
# Processing image: SatImg  (800).jpg
# Processing image: SatImg  (801).jpg
# Processing image: SatImg  (802).jpg
# Processing image: SatImg  (811).jpg
# Processing image: SatImg  (812).jpg
# Processing image: SatImg  (813).jpg
# Processing image: SatImg  (814).jpg
# Processing image: SatImg  (815).jpg
# Processing image: SatImg  (816).jpg
# Processing image: SatImg  (817).jpg
# Processing image: SatImg  (818).jpg
# Processing image: SatImg  (820).jpg
# Processing image: SatImg  (821).jpg
# Processing image: SatImg  (822).jpg
# Processing image: SatImg  (823).jpg
# Processing image: SatImg  (824).jpg
# Processing image: SatImg  (825).jpg
# Processing image: SatImg  (826).jpg
# Processing image: SatImg  (829).jpg
# Processing image: SatImg  (830).jpg
# Processing image: SatImg  (831).jpg
# Processing image: SatImg  (832).jpg
# Processing image: SatImg  (833).jpg
# Processing image: SatImg  (834).jpg
# Processing image: SatImg  (835).jpg
# Processing image: SatImg  (836).jpg
# Processing image: SatImg  (837).jpg
# Processing image: SatImg  (838).jpg
# Processing image: SatImg  (839).jpg
# Processing image: SatImg  (850).jpg
# Processing image: SatImg  (851).jpg
# Processing image: SatImg  (852).jpg
# Processing image: SatImg  (853).jpg
# Processing image: SatImg  (854).jpg
# Processing image: SatImg  (855).jpg
# Processing image: SatImg  (856).jpg
# Processing image: SatImg  (857).jpg
# Processing image: SatImg  (860).jpg
# Processing image: SatImg  (861).jpg
# Processing image: SatImg  (862).jpg
# Processing image: SatImg  (863).jpg
# Processing image: SatImg  (864).jpg
# Processing image: SatImg  (866).jpg
# Processing image: SatImg  (867).jpg
# Processing image: SatImg  (868).jpg
# Processing image: SatImg  (869).jpg
# Processing image: SatImg  (870).jpg
# Processing image: SatImg  (871).jpg
# Processing image: SatImg  (872).jpg
# Processing image: SatImg  (873).jpg
# Processing image: SatImg  (874).jpg
# Processing image: SatImg  (875).jpg
# Processing image: SatImg  (876).jpg
# Processing image: SatImg  (889).jpg
# Processing image: SatImg  (890).jpg
# Processing image: SatImg  (891).jpg
# Processing image: SatImg  (892).jpg
# Processing image: SatImg  (893).jpg
# Processing image: SatImg  (894).jpg
# Processing image: SatImg  (896).jpg
# Processing image: SatImg  (907).jpg
# Processing image: SatImg  (909).jpg
# Processing image: SatImg  (911).jpg
# Processing image: SatImg  (912).jpg
# Processing image: SatImg  (913).jpg
# Processing image: SatImg  (926).jpg
# Processing image: SatImg  (927).jpg
# Processing image: SatImg  (928).jpg
# Processing image: SatImg  (929).jpg
# Processing image: SatImg  (930).jpg
# Processing image: SatImg  (931).jpg
# Processing image: SatImg  (937).jpg
# Processing image: SatImg  (944).jpg
# Processing image: SatImg  (956).jpg
# Processing image: SatImg  (961).jpg
# Processing image: SatImg  (962).jpg
# Processing image: SatImg  (963).jpg
# Processing image: SatImg  (964).jpg
# Processing image: SatImg  (965).jpg
# Processing image: SatImg  (966).jpg
# Processing image: SatImg  (967).jpg
# Processing image: SatImg  (968).jpg
# Processing image: SatImg  (969).jpg
# Processing image: SatImg  (970).jpg
# Processing image: SatImg  (977).jpg
# Processing image: SatImg  (978).jpg
# Processing image: SatImg  (982).jpg
# Processing image: SatImg  (985).jpg
# Processing image: SatImg  (986).jpg
# Processing image: SatImg  (987).jpg
# Processing image: SatImg  (989).jpg
# Processing image: SatImg  (991).jpg
# Processing image: SatImg  (995).jpg
# Processing image: SatImg  (997).jpg
# Processing image: SatImg  (999).jpg
# Processing image: SatImg  (1000).jpg
# Processing image: SatImg  (1001).jpg
# Processing image: SatImg  (1002).jpg
# Processing image: SatImg  (1011).jpg
# Processing image: SatImg  (1012).jpg
# Processing image: SatImg  (1013).jpg
# Processing image: SatImg  (1014).jpg
# Processing image: SatImg  (1015).jpg
# Processing image: SatImg  (1016).jpg
# Processing image: SatImg  (1017).jpg
# Processing image: SatImg  (1018).jpg
# Processing image: SatImg  (1024).jpg
# Processing image: SatImg  (1028).jpg
# Processing image: SatImg  (1029).jpg
# Processing image: SatImg  (1030).jpg
# Processing image: SatImg  (1031).jpg
# Processing image: SatImg  (1033).jpg
# Processing image: SatImg  (1034).jpg
# Processing image: SatImg  (1035).jpg
# Processing image: SatImg  (1036).jpg
# Processing image: SatImg  (1037).jpg
# Processing image: SatImg  (1050).jpg
# Processing image: SatImg  (1054).jpg
# Processing image: SatImg  (1057).jpg
# Processing image: SatImg  (1065).jpg
# Processing image: SatImg  (1068).jpg
# Processing image: SatImg  (1069).jpg
# Processing image: SatImg  (1070).jpg
# Processing image: SatImg  (1080).jpg
# Processing image: SatImg  (1081).jpg
# Processing image: SatImg  (1085).jpg
# Processing image: SatImg  (1086).jpg
# Processing image: SatImg  (1087).jpg
# Processing image: SatImg  (1088).jpg
# Processing image: SatImg  (1089).jpg
# Processing image: SatImg  (1090).jpg
# Processing image: SatImg  (1091).jpg
# Processing image: SatImg  (1092).jpg
# Processing image: SatImg  (1093).jpg
# Processing image: SatImg  (1094).jpg
# Processing image: SatImg  (1095).jpg
# Processing image: SatImg  (1096).jpg
# Processing image: SatImg  (1097).jpg
# Processing image: SatImg  (1109).jpg
# Processing image: SatImg  (1110).jpg
# Processing image: SatImg  (1111).jpg
# Processing image: SatImg  (1114).jpg
# Processing image: SatImg  (1115).jpg
# Processing image: SatImg  (1117).jpg
# Processing image: SatImg  (1118).jpg
# Processing image: SatImg  (1119).jpg
# Processing image: SatImg  (1120).jpg
# Processing image: SatImg  (1125).jpg
# Processing image: SatImg  (1126).jpg
# Processing image: SatImg  (1127).jpg
# Processing image: Titan  (1).jpg
# Processing image: Titan  (2).jpg
# Processing image: Titan  (3).jpg
# Processing image: Titan  (4).jpg
# Processing image: Titan  (5).jpg
# Processing image: Titan  (6).jpg
# Processing image: Titan  (7).jpg
# Processing image: Titan  (8).jpg
# Processing image: Titan  (9).jpg
# Processing image: Titan  (10).jpg
# Processing image: Titan  (11).jpg
# Processing image: Titan  (13).jpg
# Processing image: Titan  (16).jpg
# Processing image: Titan  (17).jpg
# Processing image: Titan  (19).jpg
# Processing image: Titan  (21).jpg
# Processing image: Titan  (22).jpg
# Processing image: Titan  (26).jpg
# Processing image: Titan  (28).jpg
# Processing image: Titan  (31).jpg
# Processing image: Titan  (32).jpg
# Processing image: Titan  (34).jpg
# Processing image: Titan  (35).jpg
# Processing image: Titan  (36).jpg
# Processing image: Titan  (37).jpg
# Processing image: Titan  (39).jpg
# Processing image: Titan  (40).jpg
# Processing image: Titan  (41).jpg
# Processing image: Titan  (42).jpg
# Processing image: Titan  (44).jpg
# Processing image: Titan  (50).jpg
# Processing image: Titan  (51).jpg
# Processing image: Titan  (52).jpg
# Processing image: Titan  (53).jpg
# Processing image: Titan  (55).jpg
# Processing image: Titan  (60).jpg
# Processing image: Titan  (61).jpg
# Processing image: Titan  (62).jpg
# Processing image: Titan  (63).jpg
# Processing image: Titan  (64).jpg
# Processing image: Titan  (66).jpg
# Processing image: Titan  (69).jpg
# Processing image: Titan  (70).jpg
# Processing image: Titan  (75).jpg
# Processing image: Titan  (77).jpg
# Processing image: Titan  (85).jpg
# Processing image: Titan  (86).jpg
# Processing image: Titan  (87).jpg
# Processing image: Titan  (93).jpg
# Processing image: Titan  (98).jpg
# Processing image: Titan  (101).jpg
# Processing image: Titan  (102).jpg
# Processing image: Titan  (103).jpg
# Processing image: Titan  (106).jpg
# Processing image: Titan  (107).jpg
# Processing image: Titan  (110).jpg
# Processing image: Titan  (111).jpg
# Processing image: Titan  (112).jpg
# Processing image: Titan  (113).jpg
# Processing image: Titan  (114).jpg
# Processing image: Titan  (115).jpg
# Processing image: Titan  (116).jpg
# Processing image: Titan  (117).jpg
# Processing image: Titan  (118).jpg
# Processing image: Titan  (119).jpg
# Processing image: Titan  (120).jpg
# Processing image: Titan  (121).jpg
# Processing image: Titan  (122).jpg
# Processing image: Titan  (123).jpg
# Processing image: Titan  (124).jpg
# Processing image: Titan  (125).jpg
# Processing image: Titan  (133).jpg
# Processing image: Titan  (157).jpg
# Processing image: Titan  (159).jpg
# Processing image: Titan  (168).jpg
# Processing image: Titan  (169).jpg
# Processing image: Titan  (170).jpg
# Processing image: Titan  (171).jpg
# Processing image: Titan  (177).jpg
# Processing image: Titan  (178).jpg
# Processing image: Titan  (179).jpg
# Processing image: Titan  (180).jpg
# Processing image: Titan  (182).jpg
# Processing image: Titan  (185).jpg
# Processing image: Titan  (189).jpg
# Processing image: Titan  (201).jpg
# Processing image: Titan  (202).jpg
# Processing image: Titan  (205).jpg
# Processing image: Titan  (206).jpg
# Processing image: Titan  (207).jpg
# Processing image: Titan  (208).jpg
# Processing image: Titan  (209).jpg
# Processing image: Titan  (211).jpg
# Processing image: Titan  (215).jpg
# Processing image: Titan  (216).jpg
# Processing image: Titan  (222).jpg
# Processing image: Titan  (228).jpg
# Processing image: Titan  (230).jpg
# Processing image: Titan  (234).jpg
# Processing image: Titan  (240).jpg
# Processing image: Titan  (246).jpg
# Processing image: Titan  (249).jpg
# Processing image: Titan  (252).jpg
# Processing image: Titan  (254).jpg
# Processing image: Titan  (256).jpg
# Processing image: Titan  (266).jpg
# Processing image: Titan  (267).jpg
# Processing image: Titan  (269).jpg
# Processing image: Titan  (275).jpg
# Processing image: Titan  (278).jpg
# Processing image: Titan  (281).jpg
# Processing image: Titan  (290).jpg
# Processing image: Titan  (292).jpg
# Processing image: Titan  (293).jpg
# Processing image: Titan  (302).jpg
# Processing image: Titan  (303).jpg
# Processing image: Titan  (304).jpg
# Processing image: Titan  (305).jpg
# Processing image: Titan  (315).jpg
# Processing image: Titan  (323).jpg
# Processing image: Titan  (329).jpg
# Processing image: Titan  (331).jpg
# Processing image: Titan  (332).jpg
# Processing image: Titan  (337).jpg
# Processing image: Titan  (338).jpg
# Processing image: Titan  (340).jpg
# Processing image: Titan  (345).jpg
# Processing image: Titan  (346).jpg
# Processing image: Titan  (347).jpg
# Processing image: Titan  (348).jpg
# Processing image: Titan  (350).jpg
# Processing image: Titan  (354).jpg
# Processing image: Titan  (355).jpg
# Processing image: Titan  (356).jpg
# Processing image: Titan  (357).jpg
# Processing image: Titan  (359).jpg
# Processing image: Titan  (361).jpg
# Processing image: Titan  (362).jpg
# Processing image: Titan  (363).jpg
# Processing image: Titan  (364).jpg
# Processing image: Titan  (365).jpg
# Processing image: Titan  (366).jpg
# Processing image: Titan  (367).jpg
# Processing image: Titan  (368).jpg
# Processing image: Titan  (369).jpg
# Processing image: Titan  (370).jpg
# Processing image: Titan  (371).jpg
# Processing image: Titan  (372).jpg
# Processing image: Titan  (373).jpg
# Processing image: Titan  (374).jpg
# Processing image: Titan  (375).jpg
# Processing image: Titan  (378).jpg
# Processing image: Titan  (379).jpg
# Processing image: Titan  (380).jpg
# Processing image: Titan  (381).jpg
# Processing image: Titan  (382).jpg
# Processing image: Titan  (383).jpg
# Processing image: Titan  (384).jpg
# Processing image: Titan  (385).jpg
# Processing image: Titan  (386).jpg
# Processing image: Titan  (387).jpg
# Processing image: Titan  (388).jpg
# Processing image: Titan  (389).jpg
# Processing image: Titan  (390).jpg
# Processing image: Titan  (391).jpg
# Processing image: Titan  (392).jpg
# Processing image: Titan  (393).jpg
# Processing image: Titan  (394).jpg
# Processing image: Titan  (396).jpg
# Processing image: Titan  (397).jpg
# Processing image: Titan  (398).jpg
# Processing image: Titan  (399).jpg
# Processing image: uav  (1).jpg
# Processing image: uav  (100).jpg
# Processing image: uav  (101).jpg
# Processing image: uav  (104).jpg
# Processing image: uav  (105).jpg
# Processing image: uav  (106).jpg
# Processing image: uav  (110).jpg
# Processing image: uav  (111).jpg
# Processing image: uav  (132).jpg
# Processing image: uav  (136).jpg
# Processing image: uav  (138).jpg
# Processing image: uav  (147).jpg
# Processing image: uav  (148).jpg
# Processing image: uav  (150).jpg
# Processing image: uav  (159).jpg
# Processing image: uav  (163).jpg
# Processing image: uav  (164).jpg
# Processing image: uav  (165).jpg
# Processing image: uav  (166).jpg
# Processing image: uav  (167).jpg
# Processing image: uav  (173).jpg
# Processing image: uav  (174).jpg
# Processing image: uav  (187).jpg
# Processing image: uav  (188).jpg
# Processing image: uav  (195).jpg
# Processing image: uav  (196).jpg
# Processing image: uav  (197).jpg
# Processing image: uav  (199).jpg
# Processing image: uav  (200).jpg
# Processing image: uav  (201).jpg
# Processing image: uav  (202).jpg
# Processing image: uav  (203).jpg
# Processing image: uav  (204).jpg
# Processing image: uav  (205).jpg
# Processing image: uav  (210).jpg
# Processing image: uav  (211).jpg
# Processing image: uav  (212).jpg
# Processing image: uav  (213).jpg
# Processing image: uav  (214).jpg
# Processing image: uav  (215).jpg
# Processing image: uav  (227).jpg
# Processing image: uav  (229).jpg
# Processing image: uav  (231).jpg
# Processing image: uav  (232).jpg
# Processing image: uav  (233).jpg
# Processing image: uav  (237).jpg
# Processing image: uav  (238).jpg
# Processing image: uav  (239).jpg
# Processing image: uav  (240).jpg
# Processing image: uav  (241).jpg
# Processing image: uav  (244).jpg
# Processing image: uav  (247).jpg
# Processing image: uav  (248).jpg
# Processing image: uav  (249).jpg
# Processing image: uav  (250).jpg
# Processing image: uav  (251).jpg
# Processing image: uav  (252).jpg
# Processing image: uav  (253).jpg
# Processing image: uav  (256).jpg
# Processing image: uav  (258).jpg
# Processing image: uav  (259).jpg
# Processing image: uav  (260).jpg
# Processing image: uav  (261).jpg
# Processing image: uav  (262).jpg
# Processing image: uav  (264).jpg
# Processing image: uav  (267).jpg
# Processing image: uav  (269).jpg
# Processing image: uav  (270).jpg
# Processing image: uav  (271).jpg
# Processing image: uav  (272).jpg
# Processing image: uav  (274).jpg
# Processing image: uav  (275).jpg
# Processing image: uav  (276).jpg
# Processing image: uav  (277).jpg
# Processing image: uav  (278).jpg
# Processing image: uav  (280).jpg
# Processing image: uav  (281).jpg
# Processing image: uav  (282).jpg
# Processing image: uav  (283).jpg
# Processing image: uav  (284).jpg
# Processing image: uav  (285).jpg
# Processing image: uav  (286).jpg
# Processing image: uav  (287).jpg
# Processing image: uav  (288).jpg
# Processing image: uav  (289).jpg
# Processing image: uav  (296).jpg
# Processing image: uav  (297).jpg
# Processing image: uav  (298).jpg
# Processing image: uav  (300).jpg
# Processing image: uav  (305).jpg
# Processing image: uav  (306).jpg
# Processing image: uav  (307).jpg
# Processing image: uav  (311).jpg
# Processing image: uav  (318).jpg
# Processing image: uav  (324).jpg
# Processing image: uav  (325).jpg
# Processing image: uav  (326).jpg
# Processing image: uav  (328).jpg
# Processing image: uav  (329).jpg
# Processing image: uav  (330).jpg
# Processing image: uav  (331).jpg
# Processing image: uav  (332).jpg
# Processing image: uav  (344).jpg
# Processing image: uav  (351).jpg
# Processing image: uav  (359).jpg
# Processing image: uav  (362).jpg
# Processing image: uav  (363).jpg
# Processing image: uav  (364).jpg
# Processing image: uav  (366).jpg
# Processing image: uav  (372).jpg
# Processing image: uav  (374).jpg
# Processing image: uav  (391).jpg
# Processing image: uav  (392).jpg
# Processing image: uav  (393).jpg
# Processing image: uav  (395).jpg
# Processing image: uav  (396).jpg
# Processing image: uav  (397).jpg
# Processing image: uav  (399).jpg
# Processing image: uav  (400).jpg
# Processing image: uav  (401).jpg
# Processing image: uav  (404).jpg
# Processing image: uav  (405).jpg
# Processing image: uav  (406).jpg
# Processing image: uav  (407).jpg
# Processing image: uav  (413).jpg
# Processing image: uav  (435).jpg
# Processing image: uav  (444).jpg
# Processing image: uav  (456).jpg
# Processing image: uav  (457).jpg
# Processing image: uav  (458).jpg
# Processing image: uav  (459).jpg
# Processing image: uav  (465).jpg
# Processing image: uav  (466).jpg
# Processing image: uav  (467).jpg
# Processing image: uav  (468).jpg
# Processing image: uav  (469).jpg
# Processing image: uav  (470).jpg
# Processing image: uav  (471).jpg
# Processing image: uav  (476).jpg
# Processing image: uav  (477).jpg
# Processing image: uav  (478).jpg
# Processing image: uav  (479).jpg
# Processing image: uav  (480).jpg
# Processing image: uav  (481).jpg
# Processing image: uav  (482).jpg
# Processing image: uav  (483).jpg
# Processing image: uav  (489).jpg
# Processing image: uav  (490).jpg
# Processing image: uav  (491).jpg
# Processing image: uav  (492).jpg
# Processing image: uav  (493).jpg
# Processing image: uav  (494).jpg
# Processing image: uav  (495).jpg
# Processing image: uav  (497).jpg
# Processing image: uav  (499).jpg
# Processing image: uav  (502).jpg
# Processing image: uav  (503).jpg
# Processing image: uav  (504).jpg
# Processing image: uav  (505).jpg
# Processing image: uav  (506).jpg
# Processing image: uav  (508).jpg
# Processing image: uav  (512).jpg
# Processing image: uav  (515).jpg
# Processing image: uav  (516).jpg
# Processing image: uav  (517).jpg
# Processing image: uav  (518).jpg
# Processing image: uav  (519).jpg
# Processing image: uav  (520).jpg
# Processing image: uav  (521).jpg
# Processing image: uav  (522).jpg
# Processing image: uav  (523).jpg
# Processing image: uav  (524).jpg
# Processing image: uav  (525).jpg
# Processing image: uav  (526).jpg
# Processing image: uav  (527).jpg
# Processing image: uav  (528).jpg
# Processing image: uav  (529).jpg
# Processing image: uav  (530).jpg
# Processing image: uav  (531).jpg
# Processing image: uav  (534).jpg
# Processing image: uav  (535).jpg
# Processing image: uav  (536).jpg
# Processing image: uav  (537).jpg
# Processing image: uav  (538).jpg
# Processing image: uav  (539).jpg
# Processing image: uav  (541).jpg
# Processing image: uav  (542).jpg
# Processing image: uav  (543).jpg
# Processing image: uav  (544).jpg
# Processing image: uav  (545).jpg
# Processing image: uav  (546).jpg
# Processing image: uav  (548).jpg
# Processing image: uav  (549).jpg
# Processing image: uav  (550).jpg
# Processing image: uav  (551).jpg
# Processing image: uav  (552).jpg
# Processing image: uav  (553).jpg
# Processing image: uav  (554).jpg
# Processing image: uav  (556).jpg
# Processing image: uav  (557).jpg
# Processing image: uav  (558).jpg
# Processing image: uav  (559).jpg
# Processing image: uav  (560).jpg
# Processing image: uav  (561).jpg
# Processing image: uav  (563).jpg
# Processing image: uav  (564).jpg
# Processing image: uav  (565).jpg
# Processing image: uav  (566).jpg
# Processing image: uav  (567).jpg
# Processing image: uav  (568).jpg
# Processing image: uav  (569).jpg
# Processing image: uav  (570).jpg
# Processing image: uav  (571).jpg
# Processing image: uav  (572).jpg
# Processing image: uav  (573).jpg
# Processing image: uav  (588).jpg
# Processing image: uav  (589).jpg
# Processing image: uav  (593).jpg
# Processing image: uav  (598).jpg
# Processing image: uav  (599).jpg
# Processing image: uav  (605).jpg
# Processing image: uav  (611).jpg
# Processing image: uav  (612).jpg
# Processing image: uav  (623).jpg
# Processing image: uav  (624).jpg
# Processing image: uav  (631).jpg
# Processing image: uav  (632).jpg
# Processing image: uav  (635).jpg
# Processing image: uav  (636).jpg
# Processing image: uav  (638).jpg
# Processing image: uav  (641).jpg
# Processing image: uav  (642).jpg
# Processing image: uav  (643).jpg
# Processing image: uav  (644).jpg
# Processing image: uav  (646).jpg
# Processing image: uav  (647).jpg
# Processing image: uav  (648).jpg
# Processing image: uav  (649).jpg
# Processing image: uav  (651).jpg
# Processing image: uav  (652).jpg
# Processing image: uav  (653).jpg
# Processing image: uav  (654).jpg
# Processing image: uav  (655).jpg
# Processing image: uav  (656).jpg
# Processing image: uav  (658).jpg
# Processing image: uav  (659).jpg
# Processing image: uav  (661).jpg
# Processing image: uav  (662).jpg
# Processing image: uav  (663).jpg
# Processing image: uav  (664).jpg
# Processing image: uav  (665).jpg
# Processing image: uav  (667).jpg
# Processing image: uav  (668).jpg
# Processing image: uav  (670).jpg
# Processing image: uav  (671).jpg
# Processing image: uav  (672).jpg
# Processing image: uav  (673).jpg
# Processing image: uav  (674).jpg
# Processing image: uav  (675).jpg
# Processing image: uav  (676).jpg
# Processing image: uav  (677).jpg
# Processing image: uav  (678).jpg
# Processing image: uav  (679).jpg
# Processing image: uav  (682).jpg
# Processing image: uav  (683).jpg
# Processing image: uav  (684).jpg
# Processing image: uav  (685).jpg
# Processing image: uav  (686).jpg
# Processing image: uav  (688).jpg
# Processing image: uav  (690).jpg
# Processing image: uav  (691).jpg
# Processing image: uav  (694).jpg
# Processing image: uav  (695).jpg
# Processing image: uav  (696).jpg
# Processing image: uav  (697).jpg
# Processing image: uav  (698).jpg
# Processing image: uav  (699).jpg
# Processing image: uav  (700).jpg
# Processing image: uav  (701).jpg
# Processing image: uav  (702).jpg
# Processing image: uav  (703).jpg
# Processing image: uav  (706).jpg
# Processing image: uav  (707).jpg
# Processing image: uav  (708).jpg
# Processing image: uav  (709).jpg
# Processing image: uav  (710).jpg
# Processing image: uav  (711).jpg
# Processing image: uav  (712).jpg
# Processing image: uav  (713).jpg
# Processing image: uav  (714).jpg
# Processing image: uav  (718).jpg
# Processing image: uav  (719).jpg
# Processing image: uav  (720).jpg
# Processing image: uav  (721).jpg
# Processing image: uav  (722).jpg
# Processing image: uav  (723).jpg
# Processing image: uav  (724).jpg
# Processing image: uav  (725).jpg
# Processing image: uav  (726).jpg
# Processing image: uav  (730).jpg
# Processing image: uav  (731).jpg
# Processing image: uav  (732).jpg
# Processing image: uav  (733).jpg
# Processing image: uav  (742).jpg
# Processing image: uav  (743).jpg
# Processing image: uav  (744).jpg
# Processing image: uav  (746).jpg
# Processing image: uav  (747).jpg
# Processing image: uav  (748).jpg
# Processing image: uav  (749).jpg
# Processing image: uav  (750).jpg
# Processing image: uav  (751).jpg
# Processing image: uav  (752).jpg
# Processing image: uav  (753).jpg
# Processing image: uav  (754).jpg
# Processing image: uav  (756).jpg
# Processing image: uav  (758).jpg
# Processing image: uav  (763).jpg
# Processing image: uav  (765).jpg
# Processing image: uav  (766).jpg
# Processing image: uav  (767).jpg
# Processing image: uav  (768).jpg
# Processing image: uav  (771).jpg
# Processing image: uav  (772).jpg
# Processing image: uav  (775).jpg
# Processing image: uav  (776).jpg
# Processing image: uav  (777).jpg
# Processing image: uav  (779).jpg
# Processing image: uav  (780).jpg
# Processing image: uav  (781).jpg
# Processing image: uav  (785).jpg
# Processing image: uav  (786).jpg
# Processing image: uav  (787).jpg
# Processing image: uav  (788).jpg
# Processing image: uav  (789).jpg
# Processing image: uav  (790).jpg
# Processing image: uav  (791).jpg
# Processing image: uav  (792).jpg
# Processing image: uav  (793).jpg
# Processing image: uav  (794).jpg
# Processing image: uav  (796).jpg
# Processing image: uav  (797).jpg
# Processing image: uav  (799).jpg
# Processing image: uav  (800).jpg
# Processing image: uav  (801).jpg
# Processing image: uav  (802).jpg
# Processing image: uav  (803).jpg
# Processing image: uav  (805).jpg
# Processing image: uav  (807).jpg
# Processing image: uav  (809).jpg
# Processing image: uav  (810).jpg
# Processing image: uav  (811).jpg
# Processing image: uav  (812).jpg
# Processing image: uav  (813).jpg
# Processing image: uav  (815).jpg
# Processing image: uav  (817).jpg
# Processing image: uav  (818).jpg
# Processing image: uav  (819).jpg
# Processing image: uav  (820).jpg
# Processing image: uav  (821).jpg
# Processing image: uav  (822).jpg
# Processing image: uav  (825).jpg
# Processing image: uav  (827).jpg
# Processing image: uav  (829).jpg
# Processing image: uav  (830).jpg
# Processing image: uav  (831).jpg
# Processing image: uav  (832).jpg
# Processing image: Titan  (82).jpg
# Processing image: uav  (514).jpg
# Processing image: uav  (687).jpg
# Processing image: uav  (689).jpg
# Processing image: uav  (745).jpg
# Processing image: uav  (806).jpg
# Processing image: uav  (343).jpg
# Processing image: Titan  (105).jpg
# Processing image: Titan  (109).jpg
# Processing image: Titan  (127).jpg
# Processing image: Titan  (175).jpg
# Processing image: Titan  (176).jpg
# Processing image: Titan  (186).jpg
# Processing image: Titan  (188).jpg
# Processing image: Titan  (195).jpg
# Processing image: Titan  (199).jpg
# Processing image: Titan  (204).jpg
# Processing image: Titan  (217).jpg
# Processing image: Titan  (225).jpg
# Processing image: Titan  (236).jpg
# Processing image: Titan  (237).jpg
# Processing image: Titan  (247).jpg
# Processing image: Titan  (250).jpg
# Processing image: Titan  (251).jpg
# Processing image: Titan  (259).jpg
# Processing image: Titan  (260).jpg
# Processing image: Titan  (262).jpg
# Processing image: Titan  (263).jpg
# Processing image: Titan  (265).jpg
# Processing image: Titan  (271).jpg
# Processing image: Titan  (276).jpg
# Processing image: Titan  (299).jpg
# Processing image: Titan  (300).jpg
# Processing image: Titan  (330).jpg
# Processing image: Titan  (351).jpg
# Processing image: SatImg  (18).jpg
# Processing image: SatImg  (38).jpg
# Processing image: SatImg  (68).jpg
# Processing image: SatImg  (90).jpg
# Processing image: SatImg  (91).jpg
# Processing image: SatImg  (93).jpg
# Processing image: SatImg  (94).jpg
# Processing image: SatImg  (99).jpg
# Processing image: SatImg  (107).jpg
# Processing image: SatImg  (108).jpg
# Processing image: SatImg  (110).jpg
# Processing image: SatImg  (119).jpg
# Processing image: SatImg  (120).jpg
# Processing image: SatImg  (121).jpg
# Processing image: SatImg  (131).jpg
# Processing image: SatImg  (133).jpg
# Processing image: SatImg  (141).jpg
# Processing image: SatImg  (146).jpg
# Processing image: SatImg  (148).jpg
# Processing image: SatImg  (149).jpg
# Processing image: SatImg  (152).jpg
# Processing image: SatImg  (160).jpg
# Processing image: SatImg  (162).jpg
# Processing image: SatImg  (163).jpg
# Processing image: SatImg  (167).jpg
# Processing image: SatImg  (173).jpg
# Processing image: SatImg  (182).jpg
# Processing image: SatImg  (184).jpg
# Processing image: SatImg  (186).jpg
# Processing image: SatImg  (187).jpg
# Processing image: SatImg  (188).jpg
# Processing image: SatImg  (189).jpg
# Processing image: SatImg  (198).jpg
# Processing image: SatImg  (199).jpg
# Processing image: SatImg  (200).jpg
# Processing image: SatImg  (210).jpg
# Processing image: SatImg  (214).jpg
# Processing image: SatImg  (221).jpg
# Processing image: SatImg  (222).jpg
# Processing image: SatImg  (223).jpg
# Processing image: SatImg  (224).jpg
# Processing image: SatImg  (225).jpg
# Processing image: SatImg  (237).jpg
# Processing image: SatImg  (240).jpg
# Processing image: SatImg  (246).jpg
# Processing image: SatImg  (255).jpg
# Processing image: SatImg  (258).jpg
# Processing image: SatImg  (264).jpg
# Processing image: SatImg  (280).jpg
# Processing image: SatImg  (281).jpg
# Processing image: SatImg  (286).jpg
# Processing image: SatImg  (287).jpg
# Processing image: SatImg  (301).jpg
# Processing image: SatImg  (318).jpg
# Processing image: SatImg  (324).jpg
# Processing image: SatImg  (326).jpg
# Processing image: SatImg  (335).jpg
# Processing image: SatImg  (354).jpg
# Processing image: SatImg  (356).jpg
# Processing image: SatImg  (357).jpg
# Processing image: SatImg  (360).jpg
# Processing image: SatImg  (361).jpg
# Processing image: SatImg  (364).jpg
# Processing image: SatImg  (375).jpg
# Processing image: SatImg  (376).jpg
# Processing image: SatImg  (388).jpg
# Processing image: SatImg  (391).jpg
# Processing image: SatImg  (392).jpg
# Processing image: SatImg  (393).jpg
# Processing image: SatImg  (406).jpg
# Processing image: SatImg  (419).jpg
# Processing image: SatImg  (444).jpg
# Processing image: SatImg  (455).jpg
# Processing image: SatImg  (456).jpg
# Processing image: SatImg  (491).jpg
# Processing image: SatImg  (492).jpg
# Processing image: SatImg  (493).jpg
# Processing image: SatImg  (514).jpg
# Processing image: SatImg  (515).jpg
# Processing image: SatImg  (516).jpg
# Processing image: SatImg  (525).jpg
# Processing image: SatImg  (526).jpg
# Processing image: SatImg  (527).jpg
# Processing image: SatImg  (528).jpg
# Processing image: SatImg  (529).jpg
# Processing image: SatImg  (535).jpg
# Processing image: SatImg  (537).jpg
# Processing image: SatImg  (540).jpg
# Processing image: SatImg  (541).jpg
# Processing image: SatImg  (542).jpg
# Processing image: SatImg  (544).jpg
# Processing image: SatImg  (553).jpg
# Processing image: SatImg  (554).jpg
# Processing image: SatImg  (558).jpg
# Processing image: SatImg  (559).jpg
# Processing image: SatImg  (560).jpg
# Processing image: SatImg  (562).jpg
# Processing image: SatImg  (563).jpg
# Processing image: SatImg  (566).jpg
# Processing image: SatImg  (575).jpg
# Processing image: SatImg  (578).jpg
# Processing image: SatImg  (582).jpg
# Processing image: SatImg  (583).jpg
# Processing image: SatImg  (584).jpg
# Processing image: SatImg  (585).jpg
# Processing image: SatImg  (586).jpg
# Processing image: SatImg  (589).jpg
# Processing image: SatImg  (591).jpg
# Processing image: SatImg  (595).jpg
# Processing image: SatImg  (601).jpg
# Processing image: SatImg  (607).jpg
# Processing image: SatImg  (609).jpg
# Processing image: SatImg  (612).jpg
# Processing image: SatImg  (613).jpg
# Processing image: SatImg  (614).jpg
# Processing image: SatImg  (617).jpg
# Processing image: SatImg  (626).jpg
# Processing image: SatImg  (629).jpg
# Processing image: SatImg  (632).jpg
# Processing image: SatImg  (636).jpg
# Processing image: SatImg  (637).jpg
# Processing image: SatImg  (640).jpg
# Processing image: SatImg  (642).jpg
# Processing image: SatImg  (644).jpg
# Processing image: SatImg  (648).jpg
# Processing image: SatImg  (651).jpg
# Processing image: SatImg  (664).jpg
# Processing image: SatImg  (665).jpg
# Processing image: SatImg  (666).jpg
# Processing image: SatImg  (667).jpg
# Processing image: SatImg  (669).jpg
# Processing image: SatImg  (671).jpg
# Processing image: SatImg  (672).jpg
# Processing image: SatImg  (674).jpg
# Processing image: SatImg  (676).jpg
# Processing image: SatImg  (678).jpg
# Processing image: SatImg  (679).jpg
# Processing image: SatImg  (682).jpg
# Processing image: SatImg  (683).jpg
# Processing image: SatImg  (684).jpg
# Processing image: SatImg  (687).jpg
# Processing image: SatImg  (688).jpg
# Processing image: SatImg  (690).jpg
# Processing image: SatImg  (698).jpg
# Processing image: SatImg  (702).jpg
# Processing image: SatImg  (704).jpg
# Processing image: SatImg  (708).jpg
# Processing image: SatImg  (709).jpg
# Processing image: SatImg  (712).jpg
# Processing image: SatImg  (715).jpg
# Processing image: SatImg  (716).jpg
# Processing image: SatImg  (720).jpg
# Processing image: SatImg  (721).jpg
# Processing image: SatImg  (722).jpg
# Processing image: SatImg  (723).jpg
# Processing image: SatImg  (724).jpg
# Processing image: SatImg  (726).jpg
# Processing image: SatImg  (727).jpg
# Processing image: SatImg  (729).jpg
# Processing image: SatImg  (730).jpg
# Processing image: SatImg  (744).jpg
# Processing image: SatImg  (745).jpg
# Processing image: SatImg  (746).jpg
# Processing image: SatImg  (749).jpg
# Processing image: SatImg  (753).jpg
# Processing image: SatImg  (754).jpg
# Processing image: SatImg  (756).jpg
# Processing image: SatImg  (761).jpg
# Processing image: SatImg  (762).jpg
# Processing image: SatImg  (763).jpg
# Processing image: SatImg  (764).jpg
# Processing image: SatImg  (766).jpg
# Processing image: SatImg  (767).jpg
# Processing image: SatImg  (789).jpg
# Processing image: SatImg  (791).jpg
# Processing image: SatImg  (792).jpg
# Processing image: SatImg  (794).jpg
# Processing image: SatImg  (803).jpg
# Processing image: SatImg  (805).jpg
# Processing image: SatImg  (808).jpg
# Processing image: SatImg  (809).jpg
# Processing image: SatImg  (810).jpg
# Processing image: SatImg  (827).jpg
# Processing image: SatImg  (828).jpg
# Processing image: SatImg  (844).jpg
# Processing image: SatImg  (845).jpg
# Processing image: SatImg  (849).jpg
# Processing image: SatImg  (877).jpg
# Processing image: SatImg  (879).jpg
# Processing image: SatImg  (880).jpg
# Processing image: SatImg  (881).jpg
# Processing image: SatImg  (883).jpg
# Processing image: SatImg  (885).jpg
# Processing image: SatImg  (888).jpg
# Processing image: SatImg  (898).jpg
# Processing image: SatImg  (900).jpg
# Processing image: SatImg  (901).jpg
# Processing image: SatImg  (902).jpg
# Processing image: SatImg  (904).jpg
# Processing image: SatImg  (906).jpg
# Processing image: SatImg  (914).jpg
# Processing image: SatImg  (915).jpg
# Processing image: SatImg  (916).jpg
# Processing image: SatImg  (920).jpg
# Processing image: SatImg  (923).jpg
# Processing image: SatImg  (924).jpg
# Processing image: SatImg  (935).jpg
# Processing image: SatImg  (942).jpg
# Processing image: SatImg  (943).jpg
# Processing image: SatImg  (945).jpg
# Processing image: SatImg  (947).jpg
# Processing image: SatImg  (950).jpg
# Processing image: SatImg  (952).jpg
# Processing image: SatImg  (954).jpg
# Processing image: SatImg  (957).jpg
# Processing image: SatImg  (958).jpg
# Processing image: SatImg  (960).jpg
# Processing image: SatImg  (971).jpg
# Processing image: SatImg  (972).jpg
# Processing image: SatImg  (976).jpg
# Processing image: SatImg  (981).jpg
# Processing image: SatImg  (984).jpg
# Processing image: SatImg  (988).jpg
# Processing image: SatImg  (990).jpg
# Processing image: SatImg  (992).jpg
# Processing image: SatImg  (993).jpg
# Processing image: SatImg  (994).jpg
# Processing image: SatImg  (1004).jpg
# Processing image: SatImg  (1005).jpg
# Processing image: SatImg  (1006).jpg
# Processing image: SatImg  (1007).jpg
# Processing image: SatImg  (1008).jpg
# Processing image: SatImg  (1009).jpg
# Processing image: SatImg  (1010).jpg
# Processing image: SatImg  (1020).jpg
# Processing image: SatImg  (1021).jpg
# Processing image: SatImg  (1026).jpg
# Processing image: SatImg  (1038).jpg
# Processing image: SatImg  (1041).jpg
# Processing image: SatImg  (1042).jpg
# Processing image: SatImg  (1044).jpg
# Processing image: SatImg  (1045).jpg
# Processing image: SatImg  (1049).jpg
# Processing image: SatImg  (1061).jpg
# Processing image: SatImg  (1071).jpg
# Processing image: SatImg  (1072).jpg
# Processing image: SatImg  (1073).jpg
# Processing image: SatImg  (1074).jpg
# Processing image: SatImg  (1075).jpg
# Processing image: SatImg  (1079).jpg
# Processing image: SatImg  (1083).jpg
# Processing image: SatImg  (1105).jpg
# Processing image: SatImg  (1106).jpg
# Processing image: SatImg  (1108).jpg
# Processing image: SatImg  (1122).jpg
# Processing image: SatImg  (1123).jpg
# Processing image: Titan  (30).jpg
# Processing image: Titan  (38).jpg
# Processing image: Titan  (45).jpg
# Processing image: Titan  (65).jpg
# Processing image: SatImg  (932).jpg
# Processing image: Titan  (78).jpg
# Processing image: Titan  (80).jpg
# Processing image: Titan  (81).jpg
# Processing image: Titan  (83).jpg
# Processing image: Titan  (84).jpg
# Processing image: Titan  (92).jpg
# Processing image: uav  (510).jpg
# Processing image: uav  (347).jpg
# Processing image: uav  (354).jpg
# Processing image: Titan  (79).jpg
# Processing image: Titan  (88).jpg
# Processing image: Titan  (89).jpg
# Processing image: Titan  (90).jpg
# Processing image: Titan  (94).jpg
# Processing image: Titan  (95).jpg
# Processing image: Titan  (96).jpg
# Processing image: Titan  (97).jpg
# Processing image: Titan  (99).jpg
# Processing image: Titan  (100).jpg
# Processing image: Titan  (104).jpg
# Processing image: Titan  (108).jpg
# Processing image: Titan  (126).jpg
# Processing image: Titan  (128).jpg
# Processing image: Titan  (131).jpg
# Processing image: Titan  (132).jpg
# Processing image: Titan  (138).jpg
# Processing image: Titan  (139).jpg
# Processing image: Titan  (144).jpg
# Processing image: Titan  (150).jpg
# Processing image: Titan  (156).jpg
# Processing image: Titan  (162).jpg
# Processing image: Titan  (174).jpg
# Processing image: Titan  (187).jpg
# Processing image: Titan  (190).jpg
# Processing image: Titan  (193).jpg
# Processing image: Titan  (196).jpg
# Processing image: Titan  (210).jpg
# Processing image: Titan  (212).jpg
# Processing image: Titan  (213).jpg
# Processing image: Titan  (214).jpg
# Processing image: Titan  (218).jpg
# Processing image: Titan  (223).jpg
# Processing image: Titan  (226).jpg
# Processing image: Titan  (229).jpg
# Processing image: Titan  (235).jpg
# Processing image: Titan  (248).jpg
# Processing image: Titan  (258).jpg
# Processing image: Titan  (264).jpg
# Processing image: Titan  (270).jpg
# Processing image: Titan  (277).jpg
# Processing image: Titan  (286).jpg
# Processing image: Titan  (287).jpg
# Processing image: Titan  (289).jpg
# Processing image: Titan  (301).jpg
# Processing image: SatImg  (3).jpg
# Processing image: SatImg  (4).jpg
# Processing image: SatImg  (11).jpg
# Processing image: SatImg  (32).jpg
# Processing image: SatImg  (64).jpg
# Processing image: SatImg  (69).jpg
# Processing image: SatImg  (71).jpg
# Processing image: SatImg  (96).jpg
# Processing image: SatImg  (100).jpg
# Processing image: SatImg  (109).jpg
# Processing image: SatImg  (130).jpg
# Processing image: SatImg  (132).jpg
# Processing image: SatImg  (135).jpg
# Processing image: SatImg  (136).jpg
# Processing image: SatImg  (140).jpg
# Processing image: SatImg  (147).jpg
# Processing image: SatImg  (150).jpg
# Processing image: SatImg  (157).jpg
# Processing image: SatImg  (161).jpg
# Processing image: SatImg  (164).jpg
# Processing image: SatImg  (165).jpg
# Processing image: SatImg  (172).jpg
# Processing image: SatImg  (174).jpg
# Processing image: SatImg  (175).jpg
# Processing image: SatImg  (176).jpg
# Processing image: SatImg  (194).jpg
# Processing image: SatImg  (195).jpg
# Processing image: SatImg  (196).jpg
# Processing image: SatImg  (197).jpg
# Processing image: SatImg  (207).jpg
# Processing image: SatImg  (208).jpg
# Processing image: SatImg  (211).jpg
# Processing image: SatImg  (213).jpg
# Processing image: SatImg  (215).jpg
# Processing image: SatImg  (219).jpg
# Processing image: SatImg  (236).jpg
# Processing image: SatImg  (238).jpg
# Processing image: SatImg  (239).jpg
# Processing image: SatImg  (241).jpg
# Processing image: SatImg  (243).jpg
# Processing image: SatImg  (244).jpg
# Processing image: SatImg  (247).jpg
# Processing image: SatImg  (248).jpg
# Processing image: SatImg  (253).jpg
# Processing image: SatImg  (257).jpg
# Processing image: SatImg  (259).jpg
# Processing image: SatImg  (260).jpg
# Processing image: SatImg  (262).jpg
# Processing image: SatImg  (263).jpg
# Processing image: SatImg  (265).jpg
# Processing image: SatImg  (266).jpg
# Processing image: SatImg  (283).jpg
# Processing image: SatImg  (284).jpg
# Processing image: SatImg  (300).jpg
# Processing image: SatImg  (305).jpg
# Processing image: SatImg  (322).jpg
# Processing image: SatImg  (323).jpg
# Processing image: SatImg  (336).jpg
# Processing image: SatImg  (337).jpg
# Processing image: SatImg  (340).jpg
# Processing image: SatImg  (341).jpg
# Processing image: SatImg  (343).jpg
# Processing image: SatImg  (345).jpg
# Processing image: SatImg  (355).jpg
# Processing image: SatImg  (363).jpg
# Processing image: SatImg  (371).jpg
# Processing image: SatImg  (372).jpg
# Processing image: SatImg  (374).jpg
# Processing image: SatImg  (377).jpg
# Processing image: SatImg  (389).jpg
# Processing image: SatImg  (394).jpg
# Processing image: SatImg  (404).jpg
# Processing image: SatImg  (407).jpg
# Processing image: SatImg  (408).jpg
# Processing image: SatImg  (410).jpg
# Processing image: SatImg  (435).jpg
# Processing image: SatImg  (443).jpg
# Processing image: SatImg  (445).jpg
# Processing image: SatImg  (446).jpg
# Processing image: SatImg  (447).jpg
# Processing image: SatImg  (457).jpg
# Processing image: SatImg  (465).jpg
# Processing image: SatImg  (468).jpg
# Processing image: SatImg  (490).jpg
# Processing image: SatImg  (513).jpg
# Processing image: SatImg  (517).jpg
# Processing image: SatImg  (518).jpg
# Processing image: SatImg  (519).jpg
# Processing image: SatImg  (530).jpg
# Processing image: SatImg  (531).jpg
# Processing image: SatImg  (536).jpg
# Processing image: SatImg  (538).jpg
# Processing image: SatImg  (543).jpg
# Processing image: SatImg  (546).jpg
# Processing image: SatImg  (547).jpg
# Processing image: SatImg  (548).jpg
# Processing image: SatImg  (550).jpg
# Processing image: SatImg  (552).jpg
# Processing image: SatImg  (561).jpg
# Processing image: SatImg  (564).jpg
# Processing image: SatImg  (565).jpg
# Processing image: SatImg  (567).jpg
# Processing image: SatImg  (568).jpg
# Processing image: SatImg  (576).jpg
# Processing image: SatImg  (579).jpg
# Processing image: SatImg  (580).jpg
# Processing image: SatImg  (587).jpg
# Processing image: SatImg  (588).jpg
# Processing image: SatImg  (590).jpg
# Processing image: SatImg  (592).jpg
# Processing image: SatImg  (593).jpg
# Processing image: SatImg  (594).jpg
# Processing image: SatImg  (596).jpg
# Processing image: SatImg  (600).jpg
# Processing image: SatImg  (602).jpg
# Processing image: SatImg  (603).jpg
# Processing image: SatImg  (604).jpg
# Processing image: SatImg  (605).jpg
# Processing image: SatImg  (606).jpg
# Processing image: SatImg  (608).jpg
# Processing image: SatImg  (610).jpg
# Processing image: SatImg  (611).jpg
# Processing image: SatImg  (618).jpg
# Processing image: SatImg  (619).jpg
# Processing image: SatImg  (620).jpg
# Processing image: SatImg  (621).jpg
# Processing image: SatImg  (624).jpg
# Processing image: SatImg  (630).jpg
# Processing image: SatImg  (631).jpg
# Processing image: SatImg  (633).jpg
# Processing image: SatImg  (638).jpg
# Processing image: SatImg  (639).jpg
# Processing image: SatImg  (641).jpg
# Processing image: SatImg  (643).jpg
# Processing image: SatImg  (645).jpg
# Processing image: SatImg  (646).jpg
# Processing image: SatImg  (662).jpg
# Processing image: SatImg  (663).jpg
# Processing image: SatImg  (668).jpg
# Processing image: SatImg  (670).jpg
# Processing image: SatImg  (673).jpg
# Processing image: SatImg  (675).jpg
# Processing image: SatImg  (677).jpg
# Processing image: SatImg  (680).jpg
# Processing image: SatImg  (685).jpg
# Processing image: SatImg  (686).jpg
# Processing image: SatImg  (689).jpg
# Processing image: SatImg  (691).jpg
# Processing image: SatImg  (692).jpg
# Processing image: SatImg  (703).jpg
# Processing image: SatImg  (707).jpg
# Processing image: SatImg  (710).jpg
# Processing image: SatImg  (711).jpg
# Processing image: SatImg  (713).jpg
# Processing image: SatImg  (717).jpg
# Processing image: SatImg  (718).jpg
# Processing image: SatImg  (719).jpg
# Processing image: SatImg  (725).jpg
# Processing image: SatImg  (728).jpg
# Processing image: SatImg  (731).jpg
# Processing image: SatImg  (750).jpg
# Processing image: SatImg  (751).jpg
# Processing image: SatImg  (752).jpg
# Processing image: SatImg  (755).jpg
# Processing image: SatImg  (757).jpg
# Processing image: SatImg  (758).jpg
# Processing image: SatImg  (760).jpg
# Processing image: SatImg  (765).jpg
# Processing image: SatImg  (768).jpg
# Processing image: SatImg  (769).jpg
# Processing image: SatImg  (788).jpg
# Processing image: SatImg  (790).jpg
# Processing image: SatImg  (793).jpg
# Processing image: SatImg  (804).jpg
# Processing image: SatImg  (806).jpg
# Processing image: SatImg  (807).jpg
# Processing image: SatImg  (840).jpg
# Processing image: SatImg  (841).jpg
# Processing image: SatImg  (842).jpg
# Processing image: SatImg  (846).jpg
# Processing image: SatImg  (847).jpg
# Processing image: SatImg  (848).jpg
# Processing image: SatImg  (878).jpg
# Processing image: SatImg  (882).jpg
# Processing image: SatImg  (884).jpg
# Processing image: SatImg  (886).jpg
# Processing image: SatImg  (887).jpg
# Processing image: SatImg  (897).jpg
# Processing image: SatImg  (899).jpg
# Processing image: SatImg  (903).jpg
# Processing image: SatImg  (905).jpg
# Processing image: SatImg  (908).jpg
# Processing image: SatImg  (910).jpg
# Processing image: SatImg  (919).jpg
# Processing image: SatImg  (921).jpg
# Processing image: SatImg  (922).jpg
# Processing image: SatImg  (925).jpg
# Processing image: SatImg  (933).jpg
# Processing image: SatImg  (934).jpg
# Processing image: SatImg  (936).jpg
# Processing image: SatImg  (938).jpg
# Processing image: SatImg  (941).jpg
# Processing image: SatImg  (946).jpg
# Processing image: SatImg  (948).jpg
# Processing image: SatImg  (949).jpg
# Processing image: SatImg  (951).jpg
# Processing image: SatImg  (955).jpg
# Processing image: SatImg  (959).jpg
# Processing image: SatImg  (973).jpg
# Processing image: SatImg  (979).jpg
# Processing image: SatImg  (980).jpg
# Processing image: SatImg  (983).jpg
# Processing image: SatImg  (1003).jpg
# Processing image: SatImg  (1019).jpg
# Processing image: SatImg  (1022).jpg
# Processing image: SatImg  (1023).jpg
# Processing image: SatImg  (1027).jpg
# Processing image: SatImg  (1039).jpg
# Processing image: SatImg  (1040).jpg
# Processing image: SatImg  (1046).jpg
# Processing image: SatImg  (1047).jpg
# Processing image: SatImg  (1048).jpg
# Processing image: SatImg  (1060).jpg
# Processing image: SatImg  (1062).jpg
# Processing image: SatImg  (1063).jpg
# Processing image: SatImg  (1064).jpg
# Processing image: SatImg  (1078).jpg
# Processing image: SatImg  (1082).jpg
# Processing image: SatImg  (1103).jpg
# Processing image: SatImg  (1104).jpg
# Processing image: SatImg  (1112).jpg
# Processing image: SatImg  (1113).jpg
# Processing image: SatImg  (1116).jpg
# Processing image: SatImg  (1124).jpg
# Processing image: SatImg  (1133).jpg
# Processing image: Titan  (15).jpg
# Processing image: Titan  (20).jpg
# Processing image: Titan  (27).jpg
# Processing image: Titan  (29).jpg
# Processing image: Titan  (43).jpg
# Processing image: Titan  (47).jpg
# Processing image: Titan  (49).jpg
# Processing image: Titan  (54).jpg
# Processing image: Titan  (56).jpg
# Processing image: Titan  (59).jpg
# Processing image: Titan  (71).jpg
# Processing image: Titan  (73).jpg
# Processing image: Titan  (74).jpg
# Processing image: Titan  (76).jpg
# Processing image: Titan  (78).jpg

# %% [markdown]
# ## 4. Upload images and tags to Custom Vision

# %%
len(tagged_ims)
# Out:
# 1792

# %%
counter = 0

for i in range(0, len(tagged_ims), 64): 
    batch = tagged_ims[i:i+64]
    result = trainer.create_images_from_files(project.id, images=batch)

    counter += 1
    print(f"Uploaded batch {counter} of {math.ceil(len(tagged_ims)/64)}: {result.is_batch_successful}")
    
    if not result.is_batch_successful:
    print("Image batch upload failed.")
    for image in result.images:
        print("Image status: ", image.status)
# Out:
# Uploaded batch 1 of 28: True
# Uploaded batch 2 of 28: False
# Uploaded batch 3 of 28: True
# Uploaded batch 4 of 28: True
# Uploaded batch 5 of 28: True
# Uploaded batch 6 of 28: True
# Uploaded batch 7 of 28: True
# Uploaded batch 8 of 28: True
# Uploaded batch 9 of 28: True
# Uploaded batch 10 of 28: True
# Uploaded batch 11 of 28: True
# Uploaded batch 12 of 28: True
# Uploaded batch 13 of 28: True
# Uploaded batch 14 of 28: True
# Uploaded batch 15 of 28: True
# Uploaded batch 16 of 28: True
# Uploaded batch 17 of 28: True
# Uploaded batch 18 of 28: True
# Uploaded batch 19 of 28: True
# Uploaded batch 20 of 28: True
# Uploaded batch 21 of 28: True
# Uploaded batch 22 of 28: True
# Uploaded batch 23 of 28: True
# Uploaded batch 24 of 28: True
# Uploaded batch 25 of 28: True
# Uploaded batch 26 of 28: True
# Uploaded batch 27 of 28: True
# Uploaded batch 28 of 28: True
